# %% [markdown]
# # 전체합

# %%
import pandas as pd

# %%
b1 = pd.read_csv('전체1.소설문학.csv', encoding='utf-8')
b2 = pd.read_csv('전체2.오디오북스.csv', encoding='utf-8')
b3 = pd.read_csv('전체3.자기계발.csv', encoding='utf-8')
b4 = pd.read_csv('전체4.경제경영.csv', encoding='utf-8')
b5 = pd.read_csv('전체5.인문교양.csv', encoding='utf-8')
b6 = pd.read_csv('전체6.역사.csv', encoding='utf-8')
b7 = pd.read_csv('전체7.어린이동화.csv', encoding='utf-8')

# %%
a = []
b = []
c = []
d = []
e = []
f = []
g = []
for i in range(len(b1)):
    a.append('소설문학')
    
for i in range(len(b2)):
    b.append('오디오북스')
    
for i in range(len(b3)):
    c.append('자기계발')
    
for i in range(len(b4)):
    d.append('경제경영')

for i in range(len(b5)):
    e.append('인문교양')

for i in range(len(b6)):
    f.append('역사')

for i in range(len(b7)):
    g.append('어린이동화')

# %%
b1['genre'] = a
b2['genre'] = b
b3['genre'] = c
b4['genre'] = d
b5['genre'] = e
b6['genre'] = f
b7['genre'] = g

# %%
total = pd.concat([b1,b2,b3,b4,b5,b6,b7])

# %%
total = total.drop('Unnamed: 0', axis=1).reset_index()
total = total.drop('index', axis=1)
total
# Out:
#                      title voice                  author  publish  genre
# 0              매향리, 평화가 오다   이미나  화성시(기획),전혜진(글),김준현(사진)      화성시   소설문학
# 1     [이유영 낭독] 다정한 유전 _작은책   이유영                     강화길      아르테   소설문학
# 2                저스트 어 모멘트   이나리                     이경화        탐   소설문학
# 3                 사춘기라서 그래   조현정                     이명랑        탐   소설문학
# 4              [단편] 헤엄치는 밤   최인영                     한유주    미디어창비   소설문학
# ...                    ...   ...                     ...      ...    ...
# 1718                   땍때굴   NaN                     김이구       창비  어린이동화
# 1719                  꿈틀꿈틀   NaN                     김이구       창비  어린이동화
# 1720     어린이를 위한 안데르센 영어동화   NaN           한스 크리스티안 안데르센     팟빵북스  어린이동화
# 1721              7년 동안의 잠   유경선                     박완서  어린이작가정신  어린이동화
# 1722             잠자고 싶은 토끼    은정                 칼요한포셴엘린    쌤앤파커스  어린이동화
#
# [1723 rows x 5 columns]

# %%
total.to_csv('전체합.csv', encoding='utf-8')

# %% [markdown]
# # 댓글합

# %%
b1 = pd.read_csv('댓글1.소설문학.csv', encoding='utf-8')
b2 = pd.read_csv('댓글2.오디오북스.csv', encoding='utf-8')
b3 = pd.read_csv('댓글3.자기계발.csv', encoding='utf-8')
b4 = pd.read_csv('댓글4경제경영.csv', encoding='utf-8')
b5 = pd.read_csv('댓글5.인문교양.csv', encoding='utf-8')
b6 = pd.read_csv('댓글6.역사.csv', encoding='utf-8')
b7 = pd.read_csv('댓글7.어린이동화.csv', encoding='utf-8')

# %%
a = []
b = []
c = []
d = []
e = []
f = []
g = []
for i in range(len(b1)):
    a.append('소설문학')
    
for i in range(len(b2)):
    b.append('오디오북스')
    
for i in range(len(b3)):
    c.append('자기계발')
    
for i in range(len(b4)):
    d.append('경제경영')

for i in range(len(b5)):
    e.append('인문교양')

for i in range(len(b6)):
    f.append('역사')

for i in range(len(b7)):
    g.append('어린이동화')

# %%
b1['genre'] = a
b2['genre'] = b
b3['genre'] = c
b4['genre'] = d
b5['genre'] = e
b6['genre'] = f
b7['genre'] = g

# %%
total = pd.concat([b1,b2,b3,b4,b5,b6,b7])

# %%
total = total.drop('Unnamed: 0', axis=1).reset_index()
total = total.drop('index', axis=1)
total
# Out:
#        nickname rating              title voice         author  \
# 0          유노창민    100          저스트 어 모멘트   이나리            이경화
# 1       나이스가이72    100        [단편] 헤엄치는 밤   최인영            한유주
# 2            하브    100        [단편] 헤엄치는 밤   최인영            한유주
# 3            양수    100        [단편] 헤엄치는 밤   최인영            한유주
# 4      티씨지는부산더락    100        [단편] 헤엄치는 밤   최인영            한유주
# ...         ...    ...                ...   ...            ...
# 15526      후후후크     90   [단편] 햇볕 동동 구리 동동   NaN            윤기현
# 15527       하루유     10                임진록   NaN            김종광
# 15528  pink9964     90                오세암   NaN            정채봉
# 15529       소민맘    100             마법사 똥맨   NaN             송언
# 15530      유노창민    100  어린이를 위한 안데르센 영어동화   NaN  한스 크리스티안 안데르센
#
#                                                   review     created publish  \
# 0                                                잘들었습니다.  2020.11.06       탐
# 1                                         내용 목소리 넘 좋습니다.  2020.10.29   미디어창비
# 2      완전 내용도 장난 아니게 좋네요!! 그리고 목소리도 너무 좋아 집중해서 잘 들을 수...  2020.10.29   미디어창비
# 3                                          빠져드는 목소리입니다^^  2020.10.29   미디어창비
# 4                                             목소리 너무 좋아요  2020.10.28   미디어창비
# ...                                                  ...         ...     ...
# 15526              애들 재울때 들으려고 샀는데\n아빠가 더 재밌네요 옛날 생각도 나고  2020.01.19      창비
# 15527      설마 2시간 8분짜리가 9,900원은 아닌거죠? 구매해서 듣고나니 너무 허무하네요  2019.04.08      창비
# 15528   영화로 본적 있는데 보는 동안 눈물이 나오는 영화 오디오 북으로도 나왔네요 감동이었어요  2019.04.02      창비
# 15529                                               재밌어요  2019.12.19      창비
# 15530                                             잘들었습니다  2020.11.05    팟빵북스
#
#        genre
# 0       소설문학
# 1       소설문학
# 2       소설문학
# 3       소설문학
# 4       소설문학
# ...      ...
# 15526  어린이동화
# 15527  어린이동화
# 15528  어린이동화
# 15529  어린이동화
# 15530  어린이동화
#
# [15531 rows x 9 columns]

# %%
total.to_csv('댓글합.csv', encoding='utf-8')
