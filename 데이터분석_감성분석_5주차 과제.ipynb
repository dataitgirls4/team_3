# %%
import pandas as pd

# %%
review_list = pd.read_csv('댓글합.csv', encoding='cp949')['review'].tolist()

# %%
review_list
# Out:
# ['잘들었습니다.',
#  '내용 목소리 넘 좋습니다.',
#  '완전 내용도 장난 아니게 좋네요!! 그리고 목소리도 너무 좋아 집중해서 잘 들을 수 있어서 강추 강추!!',
#  '빠져드는 목소리입니다^^',
#  '목소리 너무 좋아요',
#  '좋네요',
#  '굿입니다',
#  '참 좋아요.',
#  '좋아요',
#  '좋은 내용입니다',
#  '단편 감사해요',
#  '잘들었습니다',
#  '잘들었습니다',
#  '잘 들어보겠습니다',
#  '즐청했읍니다',
#  '잘 들었습니다',
#  '짧지만 알찬 내용입니다',
#  '잘들었어요',
#  '너무 좋습니다!! *^^*',
#  '사돈도 소설광이시니 든든하시겠어요\r\n이번 단편 잘 들어볼게요^',
#  '좋아요',
#  '잘 들었습니다  응원합니다♥♥♥',
#  '좋아요',
#  '잘들었습니다',
#  '좋아요',
#  '감사합니다',
#  '다음이 더욱 궁금해지네요',
#  '잘들었습니다',
#  '잘 들었습니다',
#  '좋아요',
#  '듣고나니 많은 생각이 드는밤이네요',
#  '좋은내용 감사합니다.',
#  '깊은밤 드라이브 하고 싶네요',
#  '잘듣고갑니다',
#  '잘 들었습니다',
#  '잘들을께여',
#  '좋아요',
#  '좋아요',
#  '좋아요',
#  '잘 들었습니다',
#  '좋네요',
#  '잘들을께요',
#  '잘듣겠습니다',
#  '좋아요',
#  '좋아요! 잘듣겠습니다!!!',
#  '좋아요',
#  '듣기 편하네요',
#  '너무 좋아요',
#  '가을에 잘어울려요',
#  '잘 들었어요',
#  '좋아요',
#  '잘들었어요..',
#  '잘 들었습니다.',
#  '차분하면서도 흡입력이 있는게 참 듣기좋네요',
#  '감사합니다',
#  '좋아요',
#  '좋네요 감사합니다',
#  '좋아요',
#  '좋습니다',
#  '감사합니다',
#  '한편의 미스테리 영화를 보는 느낌이었어요',
#  '너무 좋네요',
#  '잘들었습니다',
#  '감사합니다',
# ...

# %%
df = pd.DataFrame(review_list)
# Out:
#                                                        0
# 0                                                잘들었습니다.
# 1                                         내용 목소리 넘 좋습니다.
# 2      완전 내용도 장난 아니게 좋네요!! 그리고 목소리도 너무 좋아 집중해서 잘 들을 수...
# 3                                          빠져드는 목소리입니다^^
# 4                                             목소리 너무 좋아요
# ...                                                  ...
# 15526            애들 재울때 들으려고 샀는데\r\n아빠가 더 재밌네요 옛날 생각도 나고
# 15527      설마 2시간 8분짜리가 9,900원은 아닌거죠? 구매해서 듣고나니 너무 허무하네요
# 15528   영화로 본적 있는데 보는 동안 눈물이 나오는 영화 오디오 북으로도 나왔네요 감동이었어요
# 15529                                               재밌어요
# 15530                                             잘들었습니다
#
# [15531 rows x 1 columns]

# %%
df.sample(100).reset_index()
# Out:
#     index                     0
# 0    9669  문성근 배우님 목소리 너무 좋네요~~
# 1    2579               가정적이시네요
# 2    4051               잘 들었습니다
# 3    8971                 잘들을게요
# 4    1051               잘 듣겠습니다
# ..    ...                   ...
# 95    393              기대되고 좋네요
# 96  11948                   좋아요
# 97   7516                 기대됩니이
# 98    832              잘들어보겠습니다
# 99   3897              잘 들었습니다!
#
# [100 rows x 2 columns]

# %%
review_list.to_csv('review_list.csv', encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-281aea29ca23> in <module>
# ----> 1 review_list.to_csv('review_list.csv', encoding='cp949')
#
# AttributeError: 'list' object has no attribute 'to_csv'
