# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
nickname = []
rating = []
title=[]
voice=[]
author=[]

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=103") #메인페이지
scroll(driver, 0.6) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
for i in range(1,len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i}]').click() #특정 책으로 들어가
    scroll(driver, 0.6) #스크롤 끝까지 내려
    html = driver.page_source
    soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
    n = int(soup2.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
    for i in range((n-3)//12+1):
        더보기 = driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]')
        더보기.click()
    time.sleep(1)
    html = driver.page_source
    soup3 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup
    for i in range(n):
        c=soup3.select('dt.title')[0].text
        a=soup3.select('h3.nickname')[i].text
        b=soup3.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
        d=soup3.select('dl.audiobook-details__info>dd')[1].text[3:]
        e=soup3.select('dl.audiobook-details__info>dd')[2].text[2:]
        nickname.append(a)
        rating.append(b)
        title.append(c)
        voice.append(d)
        author.append(e)
    driver.back() # 책 목록으로 돌아가
    scroll(driver, 0.6) #스크롤 끝까지 내려
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-10-af9f5efbe1ca> in <module>
#       1 for i in range(1,len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
# ----> 2     driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i}]').click() #특정 책으로 들어가
#       3     scroll(driver, 0.6) #스크롤 끝까지 내려
#       4     html = driver.page_source
#       5     soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <li class="audiobook-list-item-component">...</li> is not clickable at point (259, 4). Other element would receive the click: <div class="wrap">...</div>
#   (Session info: chrome=86.0.4240.198)

# %%
nickname
# Out:
# ['욱이이뻐',
#  '겁나빠른달팽이',
#  '판옥대선',
#  'ryu5084',
#  '포포popo',
#  '다니에루우',
#  '슬로우볼',
#  'henky',
#  'ha2',
#  'nachbar3',
#  '패니야',
#  'Zentomino',
#  'no10루니',
#  '해피이카',
#  'factcheck',
#  'huso',
#  '짱구인생',
#  '먹고는산다',
#  'jjmview',
#  '날윤',
#  '뿡야뿡요',
#  '양수',
#  '킹탄오브터갓스코',
#  'ㅎl든청취자',
#  'hannarae',
#  '하브',
#  '현대111',
#  '장미쥬스',
#  '아힌',
#  '시립',
#  '푸른달나흘',
#  'ozimgibi',
#  '이복남',
#  '노략질약탈',
#  '뚜엉장2003',
#  'ㄱㄹㄴㅁ',
#  'mikaya',
#  'Starbuck',
#  'truthy',
#  '화랑대',
#  '아진짜한번만',
#  '누커스',
#  '후후5168',
#  'donggrami',
#  'kumada',
#  '흐흐앙',
#  '탕탕탕탕슉',
#  '마포대교는무너졌냐이',
#  '저승사자마자',
#  '이혼계약',
#  '중국와이파이',
#  '바티스타',
#  '꺆꺆꺆',
#  '뜬구름0',
#  '세모리아',
#  '케니이이이이',
#  '박평평끝년이',
#  '빌뉴스',
#  'denty77',
#  '꾸우레복검',
#  'daca5656',
#  '머리긴스',
#  '촛불하나더',
#  'hamsik',
#  'sure132',
#  '개털',
#  '심심한걸',
#  '지나아줌마',
#  '고고잉',
#  'Django',
#  '사월엔새로운대한민국',
#  '콘유',
#  '동화고덕배',
#  '우주먼지구인사',
#  'myyy',
#  '바퀴박멸',
#  '5어여쁜girl',
#  '비스트마린',
#  '티씨지는부산더락',
#  '니스테르',
#  'aaajg1018',
#  '캐시우드',
#  'anluke',
#  'lukean',
#  'gianis',
#  'lesmise',
#  '이영섭',
#  '옐키',
#  '벙직',
#  'initialj',
#  'hipstery',
#  'fofo',
#  'amazio',
#  '즈아니',
#  '요조',
#  'conan34',
#  '시에라마',
#  'tonikroos',
#  '송강호',
#  'mukujun',
#  '시라노드베라주르크',
#  '조탕',
#  '상렬이형',
#  'yuj0715',
#  '카집',
#  '보통아니다',
#  '싱글벙글영진',
#  '흥칫뿡꽥',
#  'jinoyunu',
#  '깨달음',
#  '림킴*',
#  '던힐발란스',
#  '볼턴경',
#  '링엇',
#  '샤라샤',
#  '장유흰둥이',
#  '민민맘인',
#  'Reddington',
#  '오리곰',
#  '니나노니니노',
#  'kwackbj',
#  '크로스c',
#  'ceo7302',
#  '임충휴나전칠기명장',
#  '변경닉네임',
#  'toughguyjy',
#  'ungshin',
#  '동그니채미니',
#  '완벽완전팟방',
#  '식어빠진믹스커피',
#  '김간지방시',
#  'oversky1',
#  '네이스미스',
#  'jcwo1262',
#  '웸블리86',
#  'biotite',
#  '하바롭스크',
#  'pknu80',
#  '7790',
#  'thestone',
#  '유주han',
#  '사유의거처',
#  '간또',
#  '아도르',
#  '벅스턴',
#  '호드도어',
#  '누캄프',
#  'sailormars',
#  '필신기독야',
#  '딸순이낭',
#  'chichi04',
#  '코끼리311',
#  '부산기장갈매기들',
#  '앗싸라05',
#  '주야파파',
#  'bakhungs',
#  '새콤달콤냠냠',
#  '그때잡',
#  '혜찌니',
#  '원총수',
#  '매관magic',
#  '86Asia',
#  'SMEC',
#  'ohhhhh',
#  '아임두둥실둥실',
#  'MAJESTIC78',
#  '입장발표쓰는미전실',
#  'greathogoo',
#  'moon래빗',
#  'da같이',
#  'cowboybaby',
#  'part2',
#  '이제는변화할때',
#  '달자의시대',
#  'seh0507',
#  '묵향4746',
#  '마임',
#  '베이비붐',
#  '타운스32',
#  'Hoony1980',
#  '4주8자',
#  'HawaiiZoa',
#  '조르미0',
#  '곰문',
#  '히라0',
#  'dokyunman',
#  'whitene',
#  'mykino',
#  '생각의공간',
#  '하마놈',
#  'gghh',
#  'baikmg',
#  '아리까리요',
#  '마르크그라프',
#  '자라32',
#  '희망2015',
#  '촛불은영원해야한다',
#  'pjm5249',
#  '이매지네이션',
#  'gakgak',
#  '윰윰이지윰',
#  'Jaeyie',
#  'ddorg321',
#  '담둥',
#  'made0116',
#  '영원한자유인123',
#  '구로구오류동지니공방',
#  '영진최고',
#  '마리에따',
#  'uoiu',
#  '마카오똑',
#  'love1533',
#  '짱승히아로',
#  '물난리',
#  '청춘의나그네',
#  '눈에는 이',
#  '책으로간다',
#  'kimsfull',
#  '깡통1',
#  '욱이후배',
#  'shinmg1209',
#  'ahdcl1020',
#  '전파뚱띠',
#  '베르토르토',
#  '다시마튀각',
#  '절대지지않는다',
#  'taleban',
#  '웅크린냥이',
#  '등륜사랑해',
#  'ironman08',
#  '불갈리아',
#  'pinktulip',
#  '유로따리',
#  'Bia',
#  '하얀사슴',
#  'Chivarly',
#  '블링블링불링',
#  'sksacyhpar',
#  'hardstack7',
#  '놀아줘제발',
#  '저는그러한면을삶아오지않았습니다',
#  '나요저요',
#  '이작까',
#  '숫사슴',
#  '믿음소망사랑중엔망사',
#  '나의예쁜삶',
#  '이송',
#  '심사쑥꼬',
#  '히히덕',
#  'gj주',
#  '제발인천강등가즈아',
#  '아산둔포황소야',
#  'miltaiji',
#  '홍홍37',
#  '이좃까야',
#  '건바이건',
#  '이뿐똥꼬킹',
#  'kaineus45',
#  '바른말쟁이',
#  '베리2020',
#  'DDSD2012',
#  '세인트케이',
#  '고트프리트',
#  '민둘아',
#  '세피로트',
#  '펭수펭하펭바',
#  '요요제로',
#  'larlock',
#  'iy56',
#  '아드리아노',
#  '꼭안아주세요',
#  '심지휴',
#  '밤턴소년단',
#  '대룡리말바위',
#  '네이처파운드',
#  'victo9',
#  '새꺄라고해서미안해요',
#  'ㅂㅌㅅ',
#  '민민갠',
#  '웨인웅이',
#  'maxday',
#  '대한미국만세',
#  'handrake12',
#  's4o2o9n',
#  'KNUT',
#  '히키코모리11',
#  '레모나산임',
#  '구구구통닭',
#  '짬짜면대장',
#  '김대물',
#  'momo0511',
#  '투나브라운',
#  '이앤일',
#  '다이어트는힘들어',
#  '하미슬이',
#  '초밥귀신휸',
#  'Zssttt',
#  '그리고뭉게구름',
#  '떵깡',
#  '애국보수끝년',
#  '빠라까라빠라',
#  'mathhan',
#  '남자4호',
#  '시즈루',
#  'baboss',
#  'kwonjkim',
#  '무등산지기',
#  '우유속당근',
#  '그레이빈',
#  '은세',
#  '꼬꼬리코돌격대',
#  'anobo',
#  'GGMUFC',
#  '에스클레어',
#  'estyu',
#  '익산군',
#  '쌀까마',
#  '블루윙즈95',
#  '이스타잠재력은언제',
#  'legacykh',
#  'YSCHOI17',
#  '찾길바래',
#  '0오공0',
#  '문스타키온느',
#  'swagger',
#  '머스크VD',
#  'nc다이노스우승',
#  'sehye0n',
#  '훈00',
#  '마음이음2',
#  '제이콜',
#  'gaeulachim',
#  '히든인천러브',
#  '삼성X지털프라자',
#  '꿀펭수',
#  'mj0918',
#  '둘리집사',
#  '홍두0625',
#  'toughking',
#  '오렌지파르페',
#  '아지송',
#  '호두파파',
#  'bluejays19',
#  '풀향기5016',
#  'keniy']

# %% [markdown]
# # 계속 멈추는군.. 다른 코드를 찾아와봤다. 다시!

# %%
nickname = []
rating = []
title=[]
voice=[]
author=[]

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=103") #메인페이지
scroll(driver, 0.6) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
for i in range(1,len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    element = driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i}]')
    driver.execute_script("arguments[0].click();", element)
    scroll(driver, 0.6) #스크롤 끝까지 내려
    html = driver.page_source
    soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
    n = int(soup2.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
    for i in range((n-3)//12+1):
        더보기 = driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]')
        더보기.click()
    time.sleep(1)
    html = driver.page_source
    soup3 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup
    for i in range(n):
        c=soup3.select('dt.title')[0].text
        a=soup3.select('h3.nickname')[i].text
        b=soup3.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
        d=soup3.select('dl.audiobook-details__info>dd')[1].text[3:]
        e=soup3.select('dl.audiobook-details__info>dd')[2].text[2:]
        nickname.append(a)
        rating.append(b)
        title.append(c)
        voice.append(d)
        author.append(e)
    driver.back() # 책 목록으로 돌아가
    scroll(driver, 0.6) #스크롤 끝까지 내려

# %%
booklist = pd.DataFrame({
    'title': title,
    'nickname':nickname,
    'rating':rating,
    'voice': voice,
    'author': author
    
})

booklist
# Out:
#              title    nickname rating voice         author
# 0    나의 월급 독립 프로젝트        욱이이뻐    100                  유목민
# 1    나의 월급 독립 프로젝트     겁나빠른달팽이    100                  유목민
# 2    나의 월급 독립 프로젝트        판옥대선    100                  유목민
# 3    나의 월급 독립 프로젝트     ryu5084    100                  유목민
# 4    나의 월급 독립 프로젝트      포포popo    100                  유목민
# ..             ...         ...    ...   ...            ...
# 480     모두 거짓말을 한다       estyu     90   장병관  세스 스티븐스 다비도위츠
# 481     모두 거짓말을 한다      네이처파운드    100   장병관  세스 스티븐스 다비도위츠
# 482     모두 거짓말을 한다  꿈을볶는카페커피베이    100   장병관  세스 스티븐스 다비도위츠
# 483     모두 거짓말을 한다       keniy    100   장병관  세스 스티븐스 다비도위츠
# 484         문재인노믹스       산라몬무사     20   박민기        매일경제경제부
#
# [485 rows x 5 columns]

# %%
booklist.groupby(['title']).count()
# Out:
#                               nickname  rating  voice  author
# title
# 경제 읽어주는 남자 김광석의 2020년 경제전망           1       1      1       1
# 경제 읽어주는 남자 김광석의 [디지털 경제의 미래]         1       1      1       1
# 나의 월급 독립 프로젝트                      337     337    337     337
# 모두 거짓말을 한다                         139     139    139     139
# 문재인노믹스                               1       1      1       1
# 사람의 힘 (요약)                           2       2      2       2
# 시골 카페에서 경영을 찾다                       1       1      1       1
# 아마존 vs. 구글 미래 전쟁                     3       3      3       3

# %%
booklist.to_csv('C:/Users/USER/Desktop/데잇걸즈/데모데이/경제경영.csv', encoding='cp949')
