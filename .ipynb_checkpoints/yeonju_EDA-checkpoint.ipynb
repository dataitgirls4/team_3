# %% [markdown]
# # 글자수

# %% [markdown]
# ## 1. 팟빵 글자수

# %%
import pandas as pd
import numpy as np

# %%
pod = pd.read_csv('data/댓글합.csv', encoding='utf-8')

# %%
pod_w_review = pod[~pod['review'].isnull()]
pod_w_review['length'] = pod_w_review['review'].apply(lambda x: len(x))
np.mean(pod_w_review['length'])
# Out:
# C:\Users\Hanna Kim\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 15.006847545219639

# %% [markdown]
# ## 2. 밀리 글자수

# %%
millie = pd.read_csv('data/millie_review.csv', encoding='utf-8')

# %%
miliie_w_review = millie[~millie['review'].isnull()]
miliie_w_review['length'] = miliie_w_review['review'].apply(lambda x: len(x))
np.mean(miliie_w_review['length'])
# Out:
# 20.666666666666668

# %% [markdown]
# ## 3. 네이버 글자수

# %%
naver = pd.read_csv('data/naver_imsi_review.csv', encoding='utf-8')

# %%
naver_w_review = naver[~naver['review'].isnull()]
naver_w_review['length'] = naver_w_review['review'].apply(lambda x: len(x))
np.mean(naver_w_review['length'])
# Out:
# C:\Users\Hanna Kim\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 54.41226053639847

# %% [markdown]
# ## 4. 윌라 글자수

# %%
welaa = pd.read_csv('data/welaa_review.csv', encoding='utf-8')

# %%
welaa_w_review = welaa[~welaa['review'].isnull()]
welaa_w_review['length'] = welaa_w_review['review'].apply(lambda x: len(x))
np.mean(welaa_w_review['length'])
# Out:
# C:\Users\Hanna Kim\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 47.88952192221947

# %% [markdown]
# # 불성실한 댓글 개수

# %% [markdown]
# 팟빵 5136/15531
#
# 밀리 19/642
#
# 윌라 196/4041
#
# 네이버 50/1367

# %% [markdown]
# ## 1. 팟빵
#
# - 5109/15531

# %%
len(pod)
# Out:
# 15531

# %%
pod_test = pod_w_review[pod_w_review['length'] < 10]
pod_test[pod_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
# Out:
#        Unnamed: 0 nickname  rating              title           voice  \
# 0               0     유노창민     100          저스트 어 모멘트             이나리
# 6               6    이뿐똥꼬킹     100        [단편] 헤엄치는 밤             최인영
# 7               7      청솔모     100        [단편] 헤엄치는 밤             최인영
# 8               8  Sangyub     100        [단편] 헤엄치는 밤             최인영
# 10             10      니체짱     100        [단편] 헤엄치는 밤             최인영
# ...           ...      ...     ...                ...             ...
# 15516       15516     추웅시인     100   까칠한 아이(성우 낭독 버전)  김하루,김유림,가빈,박민기
# 15519       15519  izzione     100   까칠한 아이(성우 낭독 버전)  김하루,김유림,가빈,박민기
# 15521       15521     민주진보     100   까칠한 아이(성우 낭독 버전)  김하루,김유림,가빈,박민기
# 15529       15529      소민맘     100             마법사 똥맨             NaN
# 15530       15530     유노창민     100  어린이를 위한 안데르센 영어동화             NaN
#
#               author     review     created publish  genre  length
# ...

# %%
pod_cleansing = pod_test[pod_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
pod_cleansing[['nickname', 'title', 'review']].sample(5)
# Out:
#        nickname                 title     review
# 10733    Jaeyie      나는 왠지 대박날 것만 같아!    잘 듣겠습니다
# 7884      gremo    [세계환상문학걸작선] 행복한 왕자  너무 잘 들었어요
# 14319   우리가최욱이다  [EBS 세계문학전집] 걸리버 여행기      감사합니다
# 12547  ddorg321            모두 거짓말을 한다    잘들었읍니다.
# 5847        트윗ㅌ     [한예리 낭독] 안락 _ 작은책        좋아요

# %%
pod_cleansing = pod_test[pod_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
pod_cleansing.to_csv('data/cleansing_pod.csv', encoding='utf-8')

# %% [markdown]
# ## 2. 밀리

# %% [markdown]
# 18/642

# %%
len(millie)
# Out:
# 642

# %%
millie_test = miliie_w_review[miliie_w_review['length'] < 10]
millie_test[millie_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
# Out:
#      Unnamed: 0          nickname     created     review  length
# 98           98    외로운 예언자_581086  2020.11.18     잘들었습니다       6
# 109         109               진고래  2020.10.25     그냥 좋아요       6
# 128         128  재능있는 음유시인_993213  2020.11.20     정말 좋아요       6
# 133         133              미미모모  2020.02.04     요조 잘한다       6
# 146         146  성공한 컨설턴트_1273907  2019.11.14  철학이해하기좋아요       9
# 157         157                낭독  2020.11.15    내용이 좋아요       7
# 231         231                풍뫼  2020.01.23  웃습네미혼만재밌네       9
# 242         242   건강한 아티스트_589040  2019.02.21      감사합니다       5
# 281         281      어르스펀데르시제앙무스훈  2019.12.08   생각보다 재밌음       8
# 392         392    특별한 꿈쟁이_574469  2019.09.01      완전좋아요       5
# 415         415   재미있는 꿈쟁이_859669  2020.08.26      집중잘돼요       5
# 418         418              코코쩰리  2020.08.21    목소리 좋아요       7
# 427         427             ㅇㅅㅇ11  2019.01.21  마지막시한구절최고       9
# ...

# %%
millie_cleansing = millie_test[millie_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
millie_cleansing.to_csv('data/cleansing_millie.csv', encoding='utf-8')

# %% [markdown]
# ## 3. 윌라

# %% [markdown]
# 195/4041

# %%
len(welaa)
# Out:
# 4041

# %%
welaa_test = welaa_w_review[welaa_w_review['length'] < 10]
welaa_test[welaa_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
# Out:
#       Unnamed: 0 nickname           created      review  length
# 2              2      전미선  2020.11.28 23:32   잘들었습니다 \n       8
# 13            13      조은빛  2020.12.01 08:33   잘 들었습니다^^       9
# 18            18      조세일  2020.11.30 05:47    잘 들었어요!!       8
# 19            19      이성우  2020.11.28 17:18    잘 들었습니다        8
# 51            51      이재숙  2020.11.20 18:05       잘봤습니다       5
# ...          ...      ...               ...         ...     ...
# 3962        3962      이재민  2020.07.23 10:24  좋은책\n감사합니다       9
# 3970        3970     오빈.훈  2020.07.18 12:19         좋아요       3
# 3972        3972      임여훈  2020.07.17 14:25         좋아요       3
# 3994        3994      강고운  2020.07.13 20:50    너무 재밌어요!       8
# 4006        4006      강미진  2020.11.11 12:34   재밌게 들었습니다       9
#
# [196 rows x 5 columns]

# %% [markdown]
# ## 4. 네이버

# %% [markdown]
# 49/1367

# %%
len(naver)
# Out:
# 1367

# %%
naver_test = naver_w_review[naver_w_review['length'] < 10]
naver_test[naver_test['review'].str.contains('잘|들었습니다|좋아요|좋습니다|최고|재밌|감사|굿|고마|고맙')]
# Out:
#       Unnamed: 0         nickname           created     review  \
# 67            14              문파이  2020-07-23 17:18        좋아요
# 69            16             보리꾸리  2020-07-10 02:39      책 좋아요
# 201           14            myway  2020-07-24 23:55    ♥ 감사합니다
# 213            6             몬스터탑  2020-08-17 13:41   잘 들었습니다!
# 224            7            체리블러썸  2020-06-24 23:28    잘 들었네요.
# 233           16              rla  2020-06-07 16:45    너무 재밌어요
# 260            9         gawa****  2020-06-04 09:55  너무 좋아요~^^
# 264           13              아니루  2020-02-10 20:31        좋아요
# 288           17         donn****  2020-06-08 20:55      좋습니다.
# 314           19            바닐라라떼  2020-04-15 14:42      너무좋아요
# 326           11              마미굿  2020-02-18 01:20  잘 들었어요!!!
# 328           13               망쁘  2020-02-16 23:55       좋아요!
# 332           17         east****  2020-02-16 02:29      좋아요좋아
# 333           18               훈라  2020-02-16 00:55       좋습니다
# ...

# %% [markdown]
# # 댓글 이벤트

# %% [markdown]
# ## 네이버 오디오클립

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium.webdriver.support.ui import WebDriverWait

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver') #각자 chromedriver가 설치되어있는 주소를 입력해주세요
driver.implicitly_wait(5)
driver.get("https://audioclip.naver.com/events") #각자 맡은 카테고리 페이지 url을 입력해주세요
scroll(driver, 3)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
title = []
date = []
for i in range(len(soup.select('div.event_info_area'))):
    title.append(soup.select('div.event_info_area')[i].select('a.event_text')[0].text)
    date.append(soup.select('div.event_info_area')[i].select('span.event_info_duedate')[0].text)

# %%
a=[]
b=[]
for i in range(220):
    a.append(date[i][:10])
    b.append(date[i][-12:][:-2])

# %%
a
# Out:
# '2020.10.22'

# %%
date[0][-12:][:-2]
# Out:
# '2020.12.01'

# %%
naver_event = pd.DataFrame({
    'event_name':title,
    'evnet_start':a,
    'event_end':b
})
naver_event
# Out:
#                             event_name evnet_start   event_end
# 0      <바람과 함께 사라지다> 오디오북 무료 연재 구독 이벤트  2020.10.22  2020.12.01
# 1                      오디오클립 X 뇌새김 이벤트  2020.10.30  2020.11.30
# 2                     11월 월간 채널 구독 이벤트  2020.11.11  2020.11.30
# 3       오바마 낭독 신작 회고록 오디오북 단독 공개&특별할인!  2020.11.20  2020.11.30
# 4             쥬니버 동화나라 채널 구독하고 에코백 받자!  2020.11.17  2020.11.29
# ..                                 ...         ...         ...
# 215     조여정이 읽어주는 나쓰메 소세키 [도련님] 90% 할인  2019.05.29  2019.06.04
# 216   조여정이 읽어주는 그리스 비극 [오이디푸스왕] 90% 할인  2019.05.29  2019.06.04
# 217  이보영의 목소리로 듣는 헤밍웨이 [노인과 바다] 90% 할인  2019.05.21  2019.05.27
# 218     이대휘 오디오북 데뷔 기념! 할인쿠폰 모두 증정 이벤트  2019.05.16  2019.05.21
# 219                           오클락 페스티벌  2019.04.01  2019.05.05
#
# [220 rows x 3 columns]

# %%
naver_event = naver_event[naver_event['event_name'].str.contains('오디오북|읽어주는|듣는|목소리로')]
naver_event
# Out:
#                                 event_name evnet_start   event_end
# 0          <바람과 함께 사라지다> 오디오북 무료 연재 구독 이벤트  2020.10.22  2020.12.01
# 3           오바마 낭독 신작 회고록 오디오북 단독 공개&특별할인!  2020.11.20  2020.11.30
# 7    <나는 왜 네 말이 힘들까> 저자 낭독 콤팩트 오디오북 90% 할인  2020.11.19  2020.11.25
# 9             정유정 작가 장편소설 <28> 오디오북 90% 할인  2020.11.14  2020.11.20
# 11                    <부의 확장> 오디오북 90% 할인!  2020.11.07  2020.11.13
# ..                                     ...         ...         ...
# 210          『노르웨이의 숲』 오디오북, 단 7일간 90% 할인!  2019.06.11  2019.06.18
# 215         조여정이 읽어주는 나쓰메 소세키 [도련님] 90% 할인  2019.05.29  2019.06.04
# 216       조여정이 읽어주는 그리스 비극 [오이디푸스왕] 90% 할인  2019.05.29  2019.06.04
# 217      이보영의 목소리로 듣는 헤밍웨이 [노인과 바다] 90% 할인  2019.05.21  2019.05.27
# 218         이대휘 오디오북 데뷔 기념! 할인쿠폰 모두 증정 이벤트  2019.05.16  2019.05.21
#
# [89 rows x 3 columns]

# %%
naver_event.to_csv('data/naver_event.csv', encoding='utf-8')

# %% [markdown]
# # 어뷰징 데이터 비교하기

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='NanumSquare') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumSquare']

# %%
df = pd.DataFrame({
    '플랫폼명':['팟빵', '네이버오디오클립', '윌라'],
    '전체데이터':[15531, 1367, 4041],
    '어뷰징데이터':[5136, 50, 196]
})
df
# Out:
#        플랫폼명  전체데이터  어뷰징데이터
# 0        팟빵  15531    5136
# 1  네이버오디오클립   1367      50
# 2        윌라   4041     196

# %%
df['100'] = 100
df['ratio'] = (df['어뷰징데이터']/df['전체데이터'])*100

# %%
df
# Out:
#        플랫폼명  전체데이터  어뷰징데이터  100      ratio
# 0        팟빵  15531    5136  100  33.069345
# 1  네이버오디오클립   1367      50  100   3.657644
# 2        윌라   4041     196  100   4.850285

# %% [markdown]
# # 한나님 여기

# %%
import numpy as np
from matplotlib import pyplot as plt
import pylab

domain_percent1 = [15531, 4041, 1367]
domain_percent2 = [5136, 196, 50]

X_name = ['팟빵','윌라', '네이버오디오클립']
n_group = len(X_name)
index = np.arange(n_group)
bar_width = 0.35

pylab.figure(1)
plt.bar(index, domain_percent1, bar_width, tick_label=X_name, align='center')
plt.bar(bar_width+index, domain_percent2, bar_width, tick_label=X_name, align='center') #추가된 곳

plt.xlabel('오디오북플랫폼')
plt.ylabel('리뷰수')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import pylab

domain_percent1 = df['100']
domain_percent2 = df['ratio']

X_name = ['팟빵','윌라', '네이버오디오클립']
n_group = len(X_name)
index = np.arange(n_group)
bar_width = 0.35

pylab.figure(1)
plt.bar(index, domain_percent1, bar_width, tick_label=X_name, align='center')
plt.bar(bar_width+index, domain_percent2, bar_width, tick_label=X_name, align='center') #추가된 곳

plt.xlabel('오디오북플랫폼')
plt.ylabel('퍼센트')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
import pylab

domain_percent1 = df['100']
domain_percent2 = df['ratio']

X_name = ['팟빵','윌라', '오디오클립']
n_group = len(X_name)
index = np.arange(n_group)
bar_width = 0.55

pylab.figure(1)

plt.gca().set_facecolor('#E6F0F8')

x = plt.bar(bar_width+index, domain_percent2, bar_width, tick_label=X_name, align='center'
        , color = ['#54CAEA', "gold", "#22C463"]) #추가된 곳
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.yticks(ticks= [])
plt.gca().spines['bottom'].set_color('#00517C')
plt.xticks(color='#00517C')

for p in x.patches:
    left, bottom, width, height = p.get_bbox().bounds
    plt.annotate(f"{round(height,2)}%",(left+width/2, height+1), ha = 'center', size =15, color = '#00517C')


# plt.xlabel('오디오북플랫폼')
plt.ylabel('')
plt.title("플랫폼별 전체 댓글 대비 어뷰징 케이스 비율", color = "#00517C", size = 18)
plt.show()
