# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
nickname = []
rating = []
title=[]
voice=[]
author=[]

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=104") #메인페이지
scroll(driver, 0.6) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
for i in range(1,len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i}]').click() #특정 책으로 들어가
    scroll(driver, 0.6) #스크롤 끝까지 내려
    html = driver.page_source
    soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
    n = int(soup2.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
    for i in range((n-3)//12+1):
        더보기 = driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]')
        더보기.click()
    time.sleep(1)
    html = driver.page_source
    soup3 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup
    for i in range(n):
        c=soup3.select('dt.title')[0].text
        a=soup3.select('h3.nickname')[i].text
        b=soup3.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
        d=soup3.select('dl.audiobook-details__info>dd')[1].text[3:]
        e=soup3.select('dl.audiobook-details__info>dd')[2].text[2:]
        nickname.append(a)
        rating.append(b)
        title.append(c)
        voice.append(d)
        author.append(e)
    driver.back() # 책 목록으로 돌아가
    scroll(driver, 0.6) #스크롤 끝까지 내려
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-5-af9f5efbe1ca> in <module>
#       1 for i in range(1,len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
# ----> 2     driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i}]').click() #특정 책으로 들어가
#       3     scroll(driver, 0.6) #스크롤 끝까지 내려
#       4     html = driver.page_source
#       5     soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <li class="audiobook-list-item-component">...</li> is not clickable at point (259, 4). Other element would receive the click: <div class="wrap">...</div>
#   (Session info: chrome=86.0.4240.198)

# %% [markdown]
# # 멈추지 않는다고 하는,.. 다르 코드를 찾아와봤다...

# %%
nickname = []
rating = []
title=[]
voice=[]
author=[]

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=104") #메인페이지
scroll(driver, 0.6) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
for i in range(1,len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    element = driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i}]')
    driver.execute_script("arguments[0].click();", element)
    scroll(driver, 0.6) #스크롤 끝까지 내려
    html = driver.page_source
    soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
    n = int(soup2.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
    for i in range((n-3)//12+1):
        더보기 = driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]')
        더보기.click()
    time.sleep(1)
    html = driver.page_source
    soup3 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup
    for i in range(n):
        c=soup3.select('dt.title')[0].text
        a=soup3.select('h3.nickname')[i].text
        b=soup3.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
        d=soup3.select('dl.audiobook-details__info>dd')[1].text[3:]
        e=soup3.select('dl.audiobook-details__info>dd')[2].text[2:]
        nickname.append(a)
        rating.append(b)
        title.append(c)
        voice.append(d)
        author.append(e)
    driver.back() # 책 목록으로 돌아가
    scroll(driver, 0.6) #스크롤 끝까지 내려

# %%
booklist = pd.DataFrame({
    'title': title,
    'nickname':nickname,
    'rating':rating,
    'voice': voice,
    'author': author
    
})

booklist
# Out:
#            title    nickname rating          voice            author
# 0     잠자리 대화의 기적   Beagood14    100            이예은               김동화
# 1     잠자리 대화의 기적      에밀리채현맘    100            이예은               김동화
# 2     잠자리 대화의 기적       극복이정우    100            이예은               김동화
# 3     잠자리 대화의 기적  goodshow03    100            이예은               김동화
# 4     잠자리 대화의 기적      에너지오드리    100            이예은               김동화
# ...          ...         ...    ...            ...               ...
# 2435        운명이다       에르네스또    100  배우 문성근,작가 유시민  노무현,사람사는세상 노무현재단
# 2436        운명이다         윤갱힝    100  배우 문성근,작가 유시민  노무현,사람사는세상 노무현재단
# 2437        운명이다        페북루나    100  배우 문성근,작가 유시민  노무현,사람사는세상 노무현재단
# 2438        운명이다          꿀비    100  배우 문성근,작가 유시민  노무현,사람사는세상 노무현재단
# 2439      언어의 온도         곱단스    100            박모건               이기주
#
# [2440 rows x 5 columns]

# %%
booklist.groupby(['title']).count()
# Out:
#                         nickname  rating  voice  author
# title
# 골든아워1                        163     163    163     163
# 골든아워2                        127     127    127     127
# 내게는 아직 어려운 사람 사이               9       9      9       9
# 내려놓음 - 내 인생의 가장 행복한 결심         1       1      1       1
# 당신이 몰랐던 범죄학자 이야기              26      26     26      26
# 박사논문 엎고 스타일링                   7       7      7       7
# 사기를 읽다                       179     179    179     179
# 사랑과 연애와 결혼에 대하여               11      11     11      11
# 생각 그루터기에 앉아                    9       9      9       9
# 서른 살이 심리학에게 묻다                 1       1      1       1
# 세계는 왜 싸우는가                   314     314    314     314
# 어른이 되면 괜찮을 줄 알았다             530     530    530     530
# 어린이 성경 : 알기 쉬운 성경이야기           4       4      4       4
# 언어의 온도                         1       1      1       1
# 열하일기 첫걸음                     352     352    352     352
# 영리한 아이가 위험하다                   1       1      1       1
# 옷, 문학을 품다                     15      15     15      15
# 운명이다                         598     598    598     598
# 응급실 사용설명서                     21      21     21      21
# 응급실 이야기                       23      23     23      23
# 일본산고                           1       1      1       1
# 일하는 엄마의 자존감 공부                 9       9      9       9
# 잠자리 대화의 기적                     6       6      6       6
# 조선 최고의 문장, 이덕무를 읽다             1       1      1       1
# 직장에서 행복하게 살아남기                11      11     11      11
# 청춘의 독서                         4       4      4       4
# 친애하는 내당신에게                     4       4      4       4
# 편안하게 호흡을 합니다                  12      12     12      12

# %%
booklist.to_csv('C:/Users/USER/Desktop/데잇걸즈/데모데이/5. 인문교양.csv', encoding='cp949')
