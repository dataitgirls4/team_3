# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# # infinite crawling이 되면 댓글도 불러올 수 있지 않을까?

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(30)
driver.get("http://m.podbbang.com/audiobook/channel/?id=1778194")
scroll(driver, 5)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8"/>
# <title>들어본 이야기 | 오디오천국 팟빵</title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="telephone=no;" name="format-detection"/>
# <meta content="들어본 이야기 | 오디오천국 팟빵" property="og:title"/>
# <meta content="젊은 독자들이 사랑하는 작가 5인의 시선을 담은 앤솔러지. 촘촘한 문장으로 단단하고 아름다운 세계를 구축하는 구병모부터 한국문학의 묵직한 무게중심 권여선, 독창적인 색깔을 지닌 탁월한 이야기꾼 듀나, 세대와 시대를 사유하며 독자들을 늘 새로운 곳으로 이끄는 박솔뫼, 독보적인 한국소설의 최전선 한유주에 이르기까지 지금, 가장 주목받는 다섯 작가의 신작 소설이 수록되었다.&lt;br&gt;&lt;br&gt;
#
# '나'는 하나의 정체성에 고정되어 있는 존재인가. 나의 '몸'은 온전히 나의 것인가. 구병모, 권여선, 듀나, 박솔뫼, 한유주 다섯 명의 작가는 &lt;들어본 이야기&gt;를 통해 묻는다. '몸'을 구성하는 물리적·신체적 조건이 과연 '나'의 위치를 결정하고 대표할 수 있을지 작가들은 작품 속 여러 인물로 견고하게 그려낸다.&lt;br&gt;&lt;br&gt;
#
# ...

# %%
soup.select('h3.nickname')
# Out:
# [<h3 class="nickname" data-v-43ec9fe8="">ansuddl</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">daca5656</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">truthy</h3>]

# %% [markdown]
# # 댓글 끝까지 크롤링

# %% [markdown]
# ## 수동 '더보기'클릭

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(30)
driver.get("http://m.podbbang.com/audiobook/channel/?id=1778194")
scroll(driver, 5)
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
time.sleep(10)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
#  ## 아이디 크롤링

# %%
soup.select('h3.nickname')
# Out:
# [<h3 class="nickname" data-v-43ec9fe8="">ansuddl</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">daca5656</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">truthy</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">죽어도인천</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">메이슨그린우드</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">Jaeyie</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">ddorg321</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">날윤</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">kayak12</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">jjmview</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">대한미국만세</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">aaajg1018</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">mj0918</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">민둘아</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">estyu</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">maxday</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">umma7312</h3>,
# ...

# %%
nickname = []
for i in range(0,len(soup.select('h3.nickname'))):
    a = soup.select('h3.nickname')[i].text
    nickname.append(a)
    print(nickname)
# Out:
# ['ansuddl']
# ['ansuddl', 'daca5656']
# ['ansuddl', 'daca5656', 'truthy']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321', '날윤']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321', '날윤', 'kayak12']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321', '날윤', 'kayak12', 'jjmview']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321', '날윤', 'kayak12', 'jjmview', '대한미국만세']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321', '날윤', 'kayak12', 'jjmview', '대한미국만세', 'aaajg1018']
# ['ansuddl', 'daca5656', 'truthy', '죽어도인천', '메이슨그린우드', 'Jaeyie', 'ddorg321', '날윤', 'kayak12', 'jjmview', '대한미국만세', 'aaajg1018', 'mj0918']
# ...

# %% [markdown]
# ## 자동 '더보기'클릭

# %% [markdown]
# `driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()이 (n-3)//12+1만큼 실행되어야해

# %%
n = soup.select('div.audiobook-reviews-component.empty>h3.title>span')
n = n[0].text.split(' ')[1].strip('명')
n=int(n)
n
# Out:
# []

# %%
n
# Out:
# 209

# %%
(n-3)//12+1
# Out:
# 18

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(30)
driver.get("http://m.podbbang.com/audiobook/channel/?id=1778194")
scroll(driver, 5)
for i in range((n-3)//12+1):
    driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click()
time.sleep(10)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
#  ## 아이디 크롤링

# %%
soup.select('h3.nickname')
# Out:
# [<h3 class="nickname" data-v-43ec9fe8="">ansuddl</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">daca5656</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">truthy</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">죽어도인천</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">메이슨그린우드</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">Jaeyie</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">ddorg321</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">날윤</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">kayak12</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">jjmview</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">대한미국만세</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">aaajg1018</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">mj0918</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">민둘아</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">estyu</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">maxday</h3>,
#  <h3 class="nickname" data-v-43ec9fe8="">umma7312</h3>,
# ...

# %%
len(soup.select('h3.nickname'))
# Out:
# 209

# %% [markdown]
# ## 별점 크롤링

# %%
soup.select('div.star_rating>span')
# Out:
# [<span data-v-43ec9fe8="" style="width: 80%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 60%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
#  <span data-v-43ec9fe8="" style="width: 100%;"></span>,
# ...

# %%
soup.select('div.star_rating>span')[1].get('style').split(' ')[1][:-2]
# Out:
# '60'

# %% [markdown]
# ## 닉네임과 별점 매칭

# %%
nickname = []
stars = []

for i in range(n):
    a=soup.select('h3.nickname')[i].text
    b=soup.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
    nickname.append(a)
    stars.append(b)
    reviews=pd.DataFrame({
        'nickname': nickname,
        'stars':stars
    })
    print(reviews)
# Out:
#   nickname stars
# 0  ansuddl    80
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
# 3     죽어도인천   100
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
# 3     죽어도인천   100
# 4   메이슨그린우드   100
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
# 3     죽어도인천   100
# 4   메이슨그린우드   100
# 5    Jaeyie   100
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
# 3     죽어도인천   100
# 4   메이슨그린우드   100
# 5    Jaeyie   100
# 6  ddorg321   100
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
# 3     죽어도인천   100
# 4   메이슨그린우드   100
# 5    Jaeyie   100
# 6  ddorg321   100
# 7        날윤   100
#    nickname stars
# 0   ansuddl    80
# 1  daca5656    60
# 2    truthy   100
# 3     죽어도인천   100
# 4   메이슨그린우드   100
# ...

# %%
reviews
# Out:
#       nickname stars
# 0      ansuddl    80
# 1     daca5656    60
# 2       truthy   100
# 3        죽어도인천   100
# 4      메이슨그린우드   100
# ..         ...   ...
# 204  ironman08   100
# 205        흐흐앙   100
# 206        꿀펭수   100
# 207     베니와티타임   100
# 208    오디오북마스터   100
#
# [209 rows x 2 columns]

# %% [markdown]
# # 책 목록 -> 특정 책 -> 댓글 크롤링

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(30)
driver.get("http://m.podbbang.com/audiobooks?category_id=100")
scroll(driver, 5)
driver.find_element_by_xpath('//*[@id="audiobookIndex"]/div[2]/div/ul/li[1]').click()
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
n = soup.select('div.audiobook-reviews-component.empty>h3.title>span')
n = n[0].text.split(' ')[1].strip('명')
n=int(n)
n
# Out:
# 0

# %%
m = int(soup.select('div.audiobook-reviews-component.empty>h3.title>span')[0].text.split(' ')[1].strip('명'))
m
# Out:
# 0

# %%
nickname = []
stars = []

for i in range(n):
    a=soup.select('h3.nickname')[i].text
    b=soup.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
    nickname.append(a)
    stars.append(b)
    reviews=pd.DataFrame({
        'nickname': nickname,
        'stars':stars
    })
    print(reviews)

# %% [markdown]
# # 책 목록 -> 특정 책 -> 댓글 크롤링 -> 뒤로가기

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=100") #메인페이지
scroll(driver, 1) #스크롤 끝까지 내려
driver.find_element_by_xpath('//*[@id="audiobookIndex"]/div[2]/div/ul/li[57]').click() #특정 책으로 들어가
scroll(driver, 1) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser') # 특정 책 soup
n = int(soup.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
for i in range((n-3)//12+1):
    driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click() # 더보기 계속 클릭
time.sleep(3)
html = driver.page_source
soup2 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup

# %%
nickname = []
stars = []

for i in range(n):
    a=soup2.select('h3.nickname')[i].text
    b=soup2.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
    nickname.append(a)
    stars.append(b)
    reviews=pd.DataFrame({
        'nickname': nickname,
        'stars':stars
    })
    print(reviews)
    
driver.back()
# Out:
#   nickname stars
# 0     뜬구름0   100
#   nickname stars
# 0     뜬구름0   100
# 1   포스트폴윈터   100
#    nickname stars
# 0      뜬구름0   100
# 1    포스트폴윈터   100
# 2  Titicaca   100
#    nickname stars
# 0      뜬구름0   100
# 1    포스트폴윈터   100
# 2  Titicaca   100
# 3  푸하하하0115   100
#    nickname stars
# 0      뜬구름0   100
# 1    포스트폴윈터   100
# 2  Titicaca   100
# 3  푸하하하0115   100
# 4    스티브잡스너   100
#    nickname stars
# 0      뜬구름0   100
# 1    포스트폴윈터   100
# 2  Titicaca   100
# 3  푸하하하0115   100
# 4    스티브잡스너   100
# 5      잠띵이요   100
#    nickname stars
# 0      뜬구름0   100
# 1    포스트폴윈터   100
# 2  Titicaca   100
# 3  푸하하하0115   100
# 4    스티브잡스너   100
# 5      잠띵이요   100
# 6     서야휘야맘   100
#    nickname stars
# 0      뜬구름0   100
# 1    포스트폴윈터   100
# 2  Titicaca   100
# 3  푸하하하0115   100
# 4    스티브잡스너   100
# 5      잠띵이요   100
# 6     서야휘야맘   100
# 7    태랑나가신다   100
#      nickname stars
# 0        뜬구름0   100
# 1      포스트폴윈터   100
# 2    Titicaca   100
# 3    푸하하하0115   100
# ...

# %%
reviews
# Out:
#      nickname stars
# 0        뜬구름0   100
# 1      포스트폴윈터   100
# 2    Titicaca   100
# 3    푸하하하0115   100
# 4      스티브잡스너   100
# ..        ...   ...
# 387      da같이   100
# 388      벤리커트   100
# 389      하미슬이   100
# 390       꿀펭수   100
# 391       깨달음   100
#
# [392 rows x 2 columns]

# %% [markdown]
# # 목록 -> 책1  -> 목록 -> 책2 -> .... 반복해보자

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=100") #메인페이지
scroll(driver, 1) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))
# Out:
# 475

# %%
for i in range(len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i+1}]').click() #특정 책으로 들어가
    driver.back() # 책 목록으로 들어가
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-7ff978d06a7a> in <module>
#       1 for i in range(len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
#       2     driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i+1}]').click() #특정 책으로 들어가
# ----> 3     driver.back() # 책 목록으로 들어가
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in back(self)
#     811             driver.back()
#     812         """
# --> 813         self.execute(Command.GO_BACK)
#     814
#     815     def forward(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# ...

# %% [markdown]
# # 목록 -> 책1 -> 댓글 크롤링 -> 목록 -> 책2 -> 댓글 크롤링.... 반복해보자

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver')
driver.implicitly_wait(3)
driver.get("http://m.podbbang.com/audiobooks?category_id=100") #메인페이지
scroll(driver, 1) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
for i in range(len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i+1}]').click() #특정 책으로 들어가
    scroll(driver, 1) #스크롤 끝까지 내려
    html = driver.page_source
    soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
    n = int(soup2.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
    for i in range((n-3)//12+1):
        driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]').click() # 더보기 계속 클릭
    time.sleep(3)
    html = driver.page_source
    soup3 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup
    for i in range(n):
        a=soup3.select('h3.nickname')[i].text
        b=soup3.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
        nickname.append(a)
        stars.append(b)
    driver.back() # 책 목록으로 돌아가
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-99-fad2bee346c5> in <module>
#       1 for i in range(len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
# ----> 2     driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i+1}]').click() #특정 책으로 들어가
#       3     scroll(driver, 1) #스크롤 끝까지 내려
#       4     html = driver.page_source
#       5     soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ...

# %% [markdown]
# 위 코드가 돌아는 간다! 근데 자꾸 멈춘다.

# %%
nickname = []
rating = []

for i in range(len(soup.select('ul.audiobook-list-component__list>li.audiobook-list-item-component>h3.title'))):
    driver.find_element_by_xpath(f'//*[@id="audiobookIndex"]/div[2]/div/ul/li[{i+1}]').click() #특정 책으로 들어가
    scroll(driver, 1) #스크롤 끝까지 내려
    html = driver.page_source
    soup2 = BeautifulSoup(html, 'html.parser') #특정 책 soup
    n = int(soup2.select('div.audiobook-reviews-component>h3.title>span')[0].text.split(' ')[1].strip('명')) #n정의
    for i in range((n-3)//12+1):
        더보기 = driver.find_element_by_xpath('//*[@id="audiobookDetails"]/div[5]/div/button[1]')
        더보기.click()
    time.sleep(3)
    html = driver.page_source
    soup3 = BeautifulSoup(html, 'html.parser') #댓글 다 나와있는 soup
    for i in range(n):
        a=soup3.select('h3.nickname')[i].text
        b=soup3.select('div.star_rating>span')[i].get('style').split(' ')[1][:-2]
        nickname.append(a)
        rating.append(b)
    driver.back() # 책 목록으로 돌아가
    scroll(driver, 1) #스크롤 끝까지 내려
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-121-68e1fc52910d> in <module>
#      20         rating.append(b)
#      21     driver.back() # 책 목록으로 돌아가
# ---> 22     scroll(driver, 1) #스크롤 끝까지 내려
#
# <ipython-input-30-22477445f96b> in scroll(driver, timeout)
#      10
#      11         # Wait to load page
# ---> 12         time.sleep(scroll_pause_time)
#      13
#      14         # Calculate new scroll height and compare with last scroll height
#
# KeyboardInterrupt:

# %% [markdown]
# 위 코드로 돌리면 멈추진 않는다. 근데 책 목록에 갈 때마다 맨 밑까지 스크롤을 해야해서 너무 오래걸린다...ㅠ(일단 홀드해둠)

# %%
nickname
# Out:
# ['뜬구름0',
#  '포스트폴윈터',
#  'Titicaca',
#  '푸하하하0115',
#  '스티브잡스너',
#  '잠띵이요',
#  '서야휘야맘',
#  '태랑나가신다',
#  'jeonjh8953',
#  '꼭안아주세요',
#  '쭌팔',
#  '저는그러한면을삶아오지않았습니다',
#  'lesmise',
#  '훈00',
#  'hr8861',
#  '말랑말랑귤',
#  '안젤리나졸림',
#  'zzoozoo',
#  '짱구인생z',
#  'enomi',
#  '바나나맛우유6',
#  'chem1',
#  '미지의섬쓰리섬',
#  '전설의깜보',
#  '헬로우멜로우',
#  '아힌',
#  '뚜엉장2003',
#  '해피이카',
#  '로이야드',
#  '겁나빠른달팽이',
#  '김선화',
#  '블링블링불링',
#  'hamsik',
#  'jjmview',
#  '귀티부티',
#  'benif',
#  '너는누구니',
#  '어리굴젓좋아',
#  '웨인웅이',
#  'dkdhtlak',
#  '영즐',
#  '은바람',
#  '떵깡',
#  '청솔모',
#  '익산군',
#  'skyclassy',
#  '바티스타',
#  '이영섭',
#  '식어빠진믹스커피',
#  '두두리',
#  '듣고있어요',
#  '하마놈',
#  '변경닉네임',
#  'taisnlee',
#  '포포popo',
#  '독사황가',
#  '신화바앙패',
#  '김대물',
#  'umma7312',
#  '카집',
#  'shinmg1209',
#  'Django',
#  '흥칫뿡꽥',
#  '영진최고',
#  'mamor',
#  '딸순이낭',
#  'MAJESTIC78',
#  '스페렬방5',
#  '하드코어질럿',
#  '매관magic',
#  '겨울me12',
#  'jinjujung',
#  '밤턴소년단',
#  '벅스턴',
#  'loogie88',
#  '푸른달나흘',
#  'kimsfull',
#  'SMEC',
#  '다니에루우',
#  '하브',
# ...

# %%
nickname
# Out:
# ['유노창민',
#  '나이스가이72',
#  '하브',
#  '양수',
#  '티씨지는부산더락',
#  '주야파파',
#  '이뿐똥꼬킹',
#  '청솔모',
#  'Sangyub',
#  '변경닉네임',
#  '니체짱',
#  '마르크그라프',
#  'sksacyhpar',
#  'Chivarly',
#  'ahdcl1020',
#  '중국와이파이',
#  'kimsfull',
#  'yuj0715',
#  '꼬꼬리코돌격대',
#  '브람스00',
#  '세인트케이',
#  '미다진구',
#  '꼭안아주세요',
#  'shinmg1209',
#  '소리를먹는다',
#  '겁나빠른달팽이',
#  '블링블링불링',
#  '마임',
#  'cowboybaby',
#  '니나노니니노',
#  '도고이',
#  '코끼리311',
#  '신화바앙패',
#  '익산군',
#  'pknu80',
#  '심심한걸',
#  '블루윙즈95',
#  '벅스턴',
#  '마리에서',
#  'biotite',
#  '소크라테스형',
#  'ungshin',
#  '스케일링비더내김환',
#  '홍홍37',
#  '이혼계약',
#  'baboss',
#  'DDSD2012',
#  '하드코어질럿',
#  '건바이건',
#  '고트프리트',
#  '원총수',
#  '그레이빈',
#  'kaineus45',
#  '우유속당근',
#  '레모나산임',
#  'KNUT',
#  '짬짜면대장',
#  '대룡리말바위',
#  'ㅂㅌㅅ',
#  '밤턴소년단',
#  'handrake12',
#  'ceo7302',
#  'momo0511',
#  '축구adgj1234',
#  'initialj',
#  'swagger',
#  '나이스가이72',
#  '귀티부티',
#  '뜬구름0',
#  '티씨지는부산더락',
#  '주야파파',
#  '이뿐똥꼬킹',
#  'bsy0076',
#  'Sangyub',
#  '변경닉네임',
#  '엄um',
#  '니체짱',
#  '마르크그라프',
# ...

# %% [markdown]
# # 닉네임 중복값이 있어야 팟빵오디오북이 유의미해진다.

# %%
word_cnt = dict() 

for name in nickname: 
    if name not in word_cnt.keys(): 
        word_cnt[name] = 1 
    else: 
        word_cnt[name] += 1
print(word_cnt)
# Out:
# {'뜬구름0': 17, '포스트폴윈터': 1, 'Titicaca': 1, '푸하하하0115': 1, '스티브잡스너': 1, '잠띵이요': 5, '서야휘야맘': 1, '태랑나가신다': 1, 'jeonjh8953': 5, '꼭안아주세요': 21, '쭌팔': 1, '저는그러한면을삶아오지않았습니다': 1, 'lesmise': 5, '훈00': 5, 'hr8861': 1, '말랑말랑귤': 1, '안젤리나졸림': 1, 'zzoozoo': 1, '짱구인생z': 1, 'enomi': 1, '바나나맛우유6': 1, 'chem1': 5, '미지의섬쓰리섬': 1, '전설의깜보': 5, '헬로우멜로우': 1, '아힌': 1, '뚜엉장2003': 1, '해피이카': 5, '로이야드': 1, '겁나빠른달팽이': 25, '김선화': 1, '블링블링불링': 5, 'hamsik': 5, 'jjmview': 5, '귀티부티': 9, 'benif': 1, '너는누구니': 1, '어리굴젓좋아': 1, '웨인웅이': 5, 'dkdhtlak': 5, '영즐': 1, '은바람': 1, '떵깡': 5, '청솔모': 9, '익산군': 25, 'skyclassy': 5, '바티스타': 5, '이영섭': 1, '식어빠진믹스커피': 1, '두두리': 5, '듣고있어요': 1, '하마놈': 1, '변경닉네임': 25, 'taisnlee': 1, '포포popo': 5, '독사황가': 1, '신화바앙패': 21, '김대물': 9, 'umma7312': 5, '카집': 5, 'shinmg1209': 25, 'Django': 5, '흥칫뿡꽥': 5, '영진최고': 5, 'mamor': 1, '딸순이낭': 5, 'MAJESTIC78': 5, '스페렬방5': 1, '하드코어질럿': 21, '매관magic': 5, '겨울me12': 1, 'jinjujung': 1, '밤턴소년단': 21, '벅스턴': 21, 'loogie88': 1, '푸른달나흘': 5, 'kimsfull': 21, 'SMEC': 5, '다니에루우': 
# ...

# %%
word_cnt = dict() 

for name in nickname: 
    if name not in word_cnt.keys(): 
        word_cnt[name] = 1 
    else: 
        word_cnt[name] += 1
print(word_cnt)
# Out:
# {'유노창민': 3, '나이스가이72': 5, '하브': 1, '양수': 1, '티씨지는부산더락': 5, '주야파파': 5, '이뿐똥꼬킹': 5, '청솔모': 2, 'Sangyub': 6, '변경닉네임': 6, '니체짱': 5, '마르크그라프': 6, 'sksacyhpar': 6, 'Chivarly': 5, 'ahdcl1020': 6, '중국와이파이': 5, 'kimsfull': 5, 'yuj0715': 5, '꼬꼬리코돌격대': 6, '브람스00': 5, '세인트케이': 5, '미다진구': 5, '꼭안아주세요': 5, 'shinmg1209': 6, '소리를먹는다': 5, '겁나빠른달팽이': 6, '블링블링불링': 1, '마임': 6, 'cowboybaby': 2, '니나노니니노': 2, '도고이': 1, '코끼리311': 6, '신화바앙패': 5, '익산군': 6, 'pknu80': 6, '심심한걸': 6, '블루윙즈95': 6, '벅스턴': 5, '마리에서': 5, 'biotite': 6, '소크라테스형': 5, 'ungshin': 2, '스케일링비더내김환': 5, '홍홍37': 1, '이혼계약': 6, 'baboss': 5, 'DDSD2012': 5, '하드코어질럿': 5, '건바이건': 5, '고트프리트': 6, '원총수': 1, '그레이빈': 6, 'kaineus45': 2, '우유속당근': 1, '레모나산임': 2, 'KNUT': 6, '짬짜면대장': 1, '대룡리말바위': 6, 'ㅂㅌㅅ': 6, '밤턴소년단': 5, 'handrake12': 1, 'ceo7302': 5, 'momo0511': 6, '축구adgj1234': 6, 'initialj': 5, 'swagger': 6, '귀티부티': 2, '뜬구름0': 4, 'bsy0076': 5, '엄um': 1, '훈준용엄마': 1, '제주남45877': 2, 'kwonjkim': 3, '09abc': 1, 'HawaiiZoa': 1, '부산기장갈매기들아': 1, 'eimhomi': 1, '여친사귀고
# ...

# %%
word_cnt
# Out:
# {'유노창민': 3,
#  '나이스가이72': 5,
#  '하브': 1,
#  '양수': 1,
#  '티씨지는부산더락': 5,
#  '주야파파': 5,
#  '이뿐똥꼬킹': 5,
#  '청솔모': 2,
#  'Sangyub': 6,
#  '변경닉네임': 6,
#  '니체짱': 5,
#  '마르크그라프': 6,
#  'sksacyhpar': 6,
#  'Chivarly': 5,
#  'ahdcl1020': 6,
#  '중국와이파이': 5,
#  'kimsfull': 5,
#  'yuj0715': 5,
#  '꼬꼬리코돌격대': 6,
#  '브람스00': 5,
#  '세인트케이': 5,
#  '미다진구': 5,
#  '꼭안아주세요': 5,
#  'shinmg1209': 6,
#  '소리를먹는다': 5,
#  '겁나빠른달팽이': 6,
#  '블링블링불링': 1,
#  '마임': 6,
#  'cowboybaby': 2,
#  '니나노니니노': 2,
#  '도고이': 1,
#  '코끼리311': 6,
#  '신화바앙패': 5,
#  '익산군': 6,
#  'pknu80': 6,
#  '심심한걸': 6,
#  '블루윙즈95': 6,
#  '벅스턴': 5,
#  '마리에서': 5,
#  'biotite': 6,
#  '소크라테스형': 5,
#  'ungshin': 2,
#  '스케일링비더내김환': 5,
#  '홍홍37': 1,
#  '이혼계약': 6,
#  'baboss': 5,
#  'DDSD2012': 5,
#  '하드코어질럿': 5,
#  '건바이건': 5,
#  '고트프리트': 6,
#  '원총수': 1,
#  '그레이빈': 6,
#  'kaineus45': 2,
#  '우유속당근': 1,
#  '레모나산임': 2,
#  'KNUT': 6,
#  '짬짜면대장': 1,
#  '대룡리말바위': 6,
#  'ㅂㅌㅅ': 6,
#  '밤턴소년단': 5,
#  'handrake12': 1,
#  'ceo7302': 5,
#  'momo0511': 6,
# ...

# %%
groupby=list(set(nickname))
result=dict()
for ip in groupby:
    result[ip]=nickname.count(ip)

print(result)
# Out:
# {'oversky1': 2, '잠수함타고22년': 1, '잠띵이요': 1, '이좃까야': 1, '축구adgj1234': 6, 'jeonjh8953': 1, '하드코어질럿': 5, 'initialj': 5, '효윤아나도맛있어': 1, '소리를먹는다': 5, '한다만': 1, '그때잡': 1, '레모나산임': 2, '민둘아': 1, '스케일링비더내김환': 5, 'pjm5249': 1, 'heatty': 1, 'baboss': 5, '겁나빠른달팽이': 6, '바른말쟁이': 5, '에스클레어': 1, 'maxday': 2, 'Django': 1, 'chichi04': 1, '심심한걸': 6, 'ansuddl': 1, '치치1004': 1, '손수호의K2원정대': 1, '리비디비루바바': 1, '메이슨그린우드': 1, 'lesmise': 1, 'gj주': 1, '싱글벙글영진': 1, '이송': 1, '베니와티타임': 1, 'sure132': 1, '이매지네이션': 1, '지구공주': 1, '놀아줘제발': 2, '윰윰이지윰': 1, '오늘도화이팅': 1, '뭔지몰라요': 1, '노략질약탈': 1, '매관magic': 1, '코끼리311': 6, '애국보수끝년': 1, '전력질주80': 1, '세인트케이': 5, '슬로우볼': 1, 'eimhomi': 1, '나이스가이72': 5, 'pknu80': 6, 'umma7312': 1, 'djsjsjss': 1, '파진찬어른': 1, '사차원불여우': 1, '아드리아노': 1, 'asdfg원숭이': 1, '하얀사슴': 1, 'HawaiiZoa': 1, '날윤': 1, 'realbuy': 1, '꿀펭수': 1, 'bsy0076': 5, '심지휴': 1, '포포popo': 1, '미스터쏘니': 1, 'KNUT': 6, '다크초코빵': 1, 'YSCHOI17': 1, '앗싸라05': 2, 'mj0918': 1, 'ddorg321': 1, 'legacykh': 1, 'myyy': 2, '필신기독야': 1, 'ungshin': 2, 
# ...

# %%
len(result)
# Out:
# 286

# %%
len(word_cnt)
# Out:
# 286

# %%
over_30_dict = {}
for key in score_dict.keys() :
    if score_dict.get(key) >= 30 :
        over_30_dict[key] = score_dict.get(key)

# %%
over_2_dict = {}
for key in word_cnt.keys() :
    if word_cnt.get(key) >= 2 :
        over_2_dict[key] = word_cnt.get(key)

# %%
len(over_2_dict)
# Out:
# 80

# %%
over_2_dict = {}
for key in result.keys() :
    if result.get(key) >= 2 :
        over_2_dict[key] = result.get(key)

# %%
len(over_2_dict)
# Out:
# 80

# %%
len(nickname)
# Out:
# 550
