# %% [markdown]
# # 주간 베스트 오디오북 TOP 100

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium.webdriver.support.ui import WebDriverWait

# %%
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver') #각자 chromedriver가 설치되어있는 주소를 입력해주세요
driver.implicitly_wait(5)
driver.get("https://audioclip.naver.com/curations/98") #주간 베스트 오디오북 top100
scroll(driver, 1) #스크롤 끝까지 내려
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
url=[]
for i in range(100):
    a = soup.select('div.list_item>a.link')[i].get('href')
    b = f'https://audioclip.naver.com{a}'
    url.append(b)

# %%
url
# Out:
# ['https://audioclip.naver.com/audiobooks/50B8A14AE8',
#  'https://audioclip.naver.com/audiobooks/F78BC70BA9',
#  'https://audioclip.naver.com/audiobooks/03FA5A7101',
#  'https://audioclip.naver.com/audiobooks/9802A71D3E',
#  'https://audioclip.naver.com/audiobooks/A9D5AAB00F',
#  'https://audioclip.naver.com/audiobooks/62DB7AA75E',
#  'https://audioclip.naver.com/audiobooks/365F124A51',
#  'https://audioclip.naver.com/audiobooks/DCCE4556E8',
#  'https://audioclip.naver.com/audiobooks/C727135150',
#  'https://audioclip.naver.com/audiobooks/952524A66D',
#  'https://audioclip.naver.com/audiobooks/5F140A0161',
#  'https://audioclip.naver.com/audiobooks/818DEB6EAB',
#  'https://audioclip.naver.com/audiobooks/CA11B13570',
#  'https://audioclip.naver.com/audiobooks/69166703A3',
#  'https://audioclip.naver.com/audiobooks/C117197C00',
#  'https://audioclip.naver.com/audiobooks/EEA75F9EF4',
#  'https://audioclip.naver.com/audiobooks/A7E56F4DD3',
# ...

# %%
title=[]
author=[]
voice=[]
book_review = pd.DataFrame({
    'nickname': [],
    'created' : [],
    'review':[]
})

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver') #각자 chromedriver가 설치되어있는 주소를 입력해주세요
driver.implicitly_wait(2)
for i in url:
    review = []
    created = []
    nickname = []
    driver.get(f'{i}'+"#comment") #url입력
    scroll(driver,1)
    time.sleep(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser') #soup에 저장
    a=soup.select('div.title')[0].text #첫번째 페이지 제목
    b=soup.select('div.detail_author>span')[0].text[:-2] #첫번째 페이지 저자
    c=soup.select('div.detail_author>span')[1].text[:-3] #첫번째 페이지 목소리
    
    for box in soup.select('div.u_cbox_area'):
        if box.text.startswith("비밀 댓글입니다") | box.text.startswith("댓글이 삭제"):
            print("비댓or삭제")
        else:
            review.append(box.select('span.u_cbox_contents')[0].text)
            created.append(box.select('span.u_cbox_date')[0].text)
            nickname.append(box.select('span.u_cbox_nick')[0].text)
            
        
    imsi = pd.DataFrame({
        'nickname':nickname,
        'created': created,
        'review':review
    })
    
    for i in range(len(imsi)):
        title.append(a)
        author.append(b)
        voice.append(c)
    
    book_review = pd.concat([book_review, imsi])
    nxt_pg_num = 2
    while len(soup.select('div.u_cbox_area')) == 20:
        driver.find_element_by_xpath(f'//*[@id="cbox_module"]/div/div[7]/div/a[{nxt_pg_num%10+1}]').click()
        scroll(driver,1)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        time.sleep(1)
        for box in soup.select('div.u_cbox_area'):
            review = []
            created = []
            nickname = []
            if box.text.startswith("비밀 댓글입니다") | box.text.startswith("댓글이 삭제"):
                print("비댓or삭제")
            else:
                review.append(box.select('span.u_cbox_contents')[0].text)
                created.append(box.select('span.u_cbox_date')[0].text)
                nickname.append(box.select('span.u_cbox_nick')[0].text)
        
        nxt_pg_num += 1
        imsi = pd.DataFrame({
            'nickname':nickname,
            'created': created,
            'review':review
        })
        for i in range(len(imsi)):
            title.append(a)
            author.append(b)
            voice.append(c)

        book_review = pd.concat([book_review, imsi])
        if len(soup.select('div.u_cbox_area')) < 20:
            break
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-161-c8c42ec49d57> in <module>
#      37     nxt_pg_num = 2
#      38     while len(soup.select('div.u_cbox_area')) == 20:
# ---> 39         driver.find_element_by_xpath(f'//*[@id="cbox_module"]/div/div[7]/div/a[{nxt_pg_num%10+1}]').click()
#      40         scroll(driver,1)
#      41         html = driver.page_source
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
title=[]
author=[]
voice=[]
book_review = pd.DataFrame({
    'nickname': [],
    'created' : [],
    'review':[]
})

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver') #각자 chromedriver가 설치되어있는 주소를 입력해주세요
driver.implicitly_wait(2)
for i in url:
    review = []
    created = []
    nickname = []
    driver.get(f'{i}'+"#comment") #url입력
    scroll(driver,1)
    time.sleep(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser') #soup에 저장
    a=soup.select('div.title')[0].text #첫번째 페이지 제목
    b=soup.select('div.detail_author>span')[0].text[:-2] #첫번째 페이지 저자
    c=soup.select('div.detail_author>span')[1].text[:-3] #첫번째 페이지 목소리
    
    for box in soup.select('div.u_cbox_area'):
        if box.text.startswith("비밀 댓글입니다") | box.text.startswith("댓글이 삭제"):
            print("비댓or삭제")
        else:
            review.append(box.select('span.u_cbox_contents')[0].text)
            created.append(box.select('span.u_cbox_date')[0].text)
            nickname.append(box.select('span.u_cbox_nick')[0].text)
    
    driver.find_element_by_xpath('//*[@id="cbox_module"]/div/div[7]/div/a[3]').click()
    scroll(driver,1)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    time.sleep(1)
    for box in soup.select('div.u_cbox_area'):
        review = []
        created = []
        nickname = []
        if box.text.startswith("비밀 댓글입니다") | box.text.startswith("댓글이 삭제"):
            print("비댓or삭제")
        else:
            review.append(box.select('span.u_cbox_contents')[0].text)
            created.append(box.select('span.u_cbox_date')[0].text)
            nickname.append(box.select('span.u_cbox_nick')[0].text)
        
    imsi = pd.DataFrame({
        'nickname':nickname,
        'created': created,
        'review':review
    })
    
    for i in range(len(imsi)):
        title.append(a)
        author.append(b)
        voice.append(c)
    
    book_review = pd.concat([book_review, imsi])
    nxt_pg_num = 2
    while len(soup.select('div.u_cbox_area')) == 20:
        driver.find_element_by_xpath(f'//*[@id="cbox_module"]/div/div[7]/div/a[{nxt_pg_num%10+1}]').click()
        scroll(driver,1)
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        time.sleep(1)
        for box in soup.select('div.u_cbox_area'):
            review = []
            created = []
            nickname = []
            if box.text.startswith("비밀 댓글입니다") | box.text.startswith("댓글이 삭제"):
                print("비댓or삭제")
            else:
                review.append(box.select('span.u_cbox_contents')[0].text)
                created.append(box.select('span.u_cbox_date')[0].text)
                nickname.append(box.select('span.u_cbox_nick')[0].text)
        
        nxt_pg_num += 1
        imsi = pd.DataFrame({
            'nickname':nickname,
            'created': created,
            'review':review
        })
        for i in range(len(imsi)):
            title.append(a)
            author.append(b)
            voice.append(c)

        book_review = pd.concat([book_review, imsi])
        if len(soup.select('div.u_cbox_area')) < 20:
            break
# Out:
# 2

# %%
book_review
# Out:
#          nickname           created  \
# 0            레몬소다              6일 전
# 1               심  2020-11-21 01:28
# 2              진진  2020-11-18 09:14
# 3      CharmingMI  2020-11-16 23:20
# 4          wbkkkk  2020-11-16 01:44
# 5             박성준  2020-11-15 23:38
# 6        o21c****  2020-11-15 23:09
# 7              푸리  2020-11-15 23:05
# 8          좋좋아하니까  2020-11-15 23:02
# 9            빅시스터  2020-11-15 22:27
# 10            ss9  2020-11-15 22:05
# 11  Next Frontier  2020-11-15 19:49
# 12           긍정미소  2020-11-15 16:32
# 13       xhfhfhxh  2020-11-15 15:44
# 14         좋좋아하니까  2020-11-15 13:52
# 15             곰돌  2020-11-14 19:44
# 16             진진  2020-11-14 17:48
# 17       book****  2020-11-14 15:51
# 18       pichola3  2020-11-14 12:22
# 19             쏠라  2020-11-14 08:19
# 0             봄이맘  2020-11-05 14:05
#
#                                                review
# 0   너무 많은 인물들이 죽어서 슬프네요 개들과 다시 설원을 달리는 해피 엔딩이되길바랬는...
# ...

# %%
soup
# Out:
# <html data-react-helmet="id,lang,data-useragent" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36" id="frameHtml" lang="ko"><head><meta charset="utf-8"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="telephone=no" name="format-detection"/><meta content="audioclip" name="napp-aod-player"/><meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover" name="viewport"/><meta content="오디오 클립" property="al:ios:app_name"/><meta content="1192635213" property="al:ios:app_store_id"/><title>28 : 오디오클립</title><link href="https://ssl.pstatic.net/static/audio/img/icon/favicon.ico" rel="shortcut icon"/><link href="https://ssl.pstatic.net/static/audio/img/icon/android-icon-72x72.png" rel="apple-touch-icon-precomposed"/><link href="https://ssl.pstatic.net/static/audio/img/icon/android-icon-96x96.png" rel="apple-touch-icon-precomposed" sizes="96x96"/><link h
# ...

# %%
driver = webdriver.Chrome('C:/Users/USER/Desktop/데잇걸즈/파이썬/[어수웅] 파이썬 프로그래밍/chromedriver') #각자 chromedriver가 설치되어있는 주소를 입력해주세요
driver.implicitly_wait(2)
for i in url:
    review = []
    created = []
    nickname = []
    driver.get(f'{i}'+"#comment") #url입력
    scroll(driver,1)
    time.sleep(3)
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser') #soup에 저장
    a=soup.select('div.title')[0].text #첫번째 페이지 제목
    b=soup.select('div.detail_author>span')[0].text[:-2] #첫번째 페이지 저자
    c=soup.select('div.detail_author>span')[1].text[:-3] #첫번째 페이지 목소리
    
    for box in soup.select('div.u_cbox_area'):
        if box.text.startswith("비밀 댓글입니다") | box.text.startswith("댓글이 삭제"):
            print("비댓or삭제")
        else:
            review.append(box.select('span.u_cbox_contents')[0].text)
            created.append(box.select('span.u_cbox_date')[0].text)
            nickname.append(box.select('span.u_cbox_nick')[0].text)
        
    imsi = pd.DataFrame({
        'nickname':nickname,
        'created': created,
        'review':review
    })
    
    for i in range(len(imsi)):
        title.append(a)
        author.append(b)
        voice.append(c)
    
    book_review = pd.concat([book_review, imsi])
    nxt_pg_num = 2
# Out:
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제
# 비댓or삭제

# %%
book_review
# Out:
#       nickname           created  \
# 0         레몬소다              6일 전
# 1            심  2020-11-21 01:28
# 2           진진  2020-11-18 09:14
# 3   CharmingMI  2020-11-16 23:20
# 4       wbkkkk  2020-11-16 01:44
# ..         ...               ...
# 7          오뿡뎅  2020-06-17 13:47
# 8          빗소리  2020-06-17 07:04
# 9       HB9588  2020-06-14 03:07
# 10     우나이 가가멜  2020-04-07 01:12
# 11          먼지  2020-03-18 02:23
#
#                                                review
# 0   너무 많은 인물들이 죽어서 슬프네요 개들과 다시 설원을 달리는 해피 엔딩이되길바랬는...
# 1   오디오북을 쭉 이용해 보니 좋아하는 작품을 다시읽기 참 좋더라구요. 그래서 성우님이...
# 2   처음엔 재밌어으나 들으면 들을수록 마음이 아파요. 이세상에서 언젠가는 벌어질일이라고...
# 3   주말동안 다 못들어서 결국 대여했다능 ......이미 책으로 읽었지만 오디오북으로 ...
# 4   예전에 출간되자마자 책으로 읽었었는데이렇게 귀로 들으니깐 더 흡입력이 좋은거 같아요...
# ..                                                ...
# 7                             현재 우리나라가 처한 상황 같아 슬프네요.
# 8                               재밌고 쉽게 귀에.쏙쏙 들어와 좋았어요
# 9   동물농장 처음 읽었을 때가 생각이 나네요. 참 재미있게 읽었던 책인데.. 탐욕적인 ...
# ...

# %%
book_review['title'] = title

# %%
book_review.groupby('title').count()
# Out:
#                                   nickname  created  review
# title
# 1984 (민음사 세계문학, 완독본)                    16       16      16
# 28                                      40       40      40
# 90년생이 온다                                20       20      20
# <일곱 해의 마지막> 완전판 오디오북 (김연수 작가 낭독)         6        6       6
# ABC 살인 사건                                7        7       7
# ...                                    ...      ...     ...
# 타인의 시선을 의식해 힘든 나에게                      17       17      17
# 페스트 (민음사 세계문학, 완독본)                     20       20      20
# 프리즘(손원평 장편소설)                           16       16      16
# 하루 5분 뇌과학 공부법                            1        1       1
# 하버드 첫 강의 시간관리 수업 1권                      4        4       4
#
# [94 rows x 3 columns]

# %%
book_review['author'] = author
book_review['voice'] = voice

# %%
import pandas as pd

# %%
pd.read_csv('C:/Users/USER/Desktop/깃헙코웤/team_3/data/naver_imsi_review.csv', encoding='utf-8').columns
# Out:
# Index(['Unnamed: 0', 'nickname', 'created', 'review', 'title', 'author',
#        'voice'],
#       dtype='object')
